# %% [markdown]
# <h1 style='color:blue'>Assigments related to Pandas using Tips dataset</h1>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load tips data into df
df = sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# <h2 style='color:red'>Retrieving Data </h2>

# %% [markdown]
# #### Display first 10 rows

# %%
df.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %% [markdown]
# #### Display column names

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %% [markdown]
# #### Find out how many columns are of type object and how many numeric

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %% [markdown]
# #### Display all summaries related to total_bill and tip

# %%
df[['total_bill','tip']].describe()
# Out:
#        total_bill         tip
# count  244.000000  244.000000
# mean    19.785943    2.998279
# std      8.902412    1.383638
# min      3.070000    1.000000
# 25%     13.347500    2.000000
# 50%     17.795000    2.900000
# 75%     24.127500    3.562500
# max     50.810000   10.000000

# %% [markdown]
# #### Display datatype of size column

# %%
df['size'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# #### Display all unique values in column day

# %%
df['day'].unique()
# Out:
# [Sun, Sat, Thur, Fri]
# Categories (4, object): [Sun, Sat, Thur, Fri]

# %% [markdown]
# #### Display rows where sex is Female and day is Sunday

# %%
df[(df['sex'] == 'Female') & (df['day'] == 'Sun')]
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 0         16.99  1.01  Female     No  Sun  Dinner     2
# 4         24.59  3.61  Female     No  Sun  Dinner     4
# 11        35.26  5.00  Female     No  Sun  Dinner     4
# 14        14.83  3.02  Female     No  Sun  Dinner     2
# 16        10.33  1.67  Female     No  Sun  Dinner     3
# 18        16.97  3.50  Female     No  Sun  Dinner     3
# 51        10.29  2.60  Female     No  Sun  Dinner     2
# 52        34.81  5.20  Female     No  Sun  Dinner     4
# 114       25.71  4.00  Female     No  Sun  Dinner     3
# 115       17.31  3.50  Female     No  Sun  Dinner     2
# 155       29.85  5.14  Female     No  Sun  Dinner     5
# 157       25.00  3.75  Female     No  Sun  Dinner     4
# 158       13.39  2.61  Female     No  Sun  Dinner     2
# 162       16.21  2.00  Female     No  Sun  Dinner     3
# 164       17.51  3.00  Female    Yes  Sun  Dinner     2
# 178        9.60  4.00  Female    Yes  Sun  Dinner     2
# 186       20.90  3.50  Female    Yes  Sun  Dinner     3
# 188       18.15  3.50  Female    Yes  Sun  Dinner     3

# %% [markdown]
# #### Display second column value in 5th row

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.iloc[4,1]
# Out:
# 3.61

# %% [markdown]
# #### Display rows where size is 2,4 or 6

# %%
df[df['size'].isin([2,4,6])]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# 15        21.58  3.92    Male     No   Sun  Dinner     2
# 20        17.92  4.08    Male     No   Sat  Dinner     2
# 21        20.29  2.75  Female     No   Sat  Dinner     2
# 22        15.77  2.23  Female     No   Sat  Dinner     2
# 23        39.42  7.58    Male     No   Sat  Dinner     4
# 24        19.82  3.18    Male     No   Sat  Dinner     2
# 25        17.81  2.34    Male     No   Sat  Dinner     4
# 26        13.37  2.00    Male     No   Sat  Dinner     2
# 27        12.69  2.00    Male     No   Sat  Dinner     2
# 28        21.70  4.30    Male     No   Sat  Dinner     2
# 29        19.65  3.00  Female     No   Sat  Dinner     2
# 30         9.55  1.45    Male     No   Sat  Dinner     2
# 31        18.35  2.50    Male     No   Sat  Dinner     4
# 32        15.06  3.00  Female     No   Sat  Dinner     2
# 33        20.69  2.45  Female     No   Sat  Dinner     4
# 34        17.78  3.27    Male     No   Sat  Dinner     2
# 41        17.46  2.54    Male     No   Sun  Dinner     2
# ..          ...   ...     ...    ...   ...     ...   ...
# 204       20.53  4.00    Male    Yes  Thur   Lunch     4
# 207       38.73  3.00    Male    Yes   Sat  Dinner     4
# 208       24.27  2.03    Male    Yes   Sat  Dinner     2
# 209       12.76  2.23  Female    Yes   Sat  Dinner     2
# 211       25.89  5.16    Male    Yes   Sat  Dinner     4
# 212       48.33  9.00    Male     No   Sat  Dinner     4
# 213       13.27  2.50  Female    Yes   Sat  Dinner     2
# 215       12.90  1.10  Female    Yes   Sat  Dinner     2
# 217       11.59  1.50    Male    Yes   Sat  Dinner     2
# 218        7.74  1.44    Male    Yes   Sat  Dinner     2
# 219       30.14  3.09  Female    Yes   Sat  Dinner     4
# 220       12.16  2.20    Male    Yes   Fri   Lunch     2
# 221       13.42  3.48  Female    Yes   Fri   Lunch     2
# 224       13.42  1.58    Male    Yes   Fri   Lunch     2
# 225       16.27  2.50  Female    Yes   Fri   Lunch     2
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2
# 227       20.45  3.00    Male     No   Sat  Dinner     4
# 228       13.28  2.72    Male     No   Sat  Dinner     2
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2
# 230       24.01  2.00    Male    Yes   Sat  Dinner     4
# 232       11.61  3.39    Male     No   Sat  Dinner     2
# 233       10.77  1.47    Male     No   Sat  Dinner     2
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2
# 235       10.07  1.25    Male     No   Sat  Dinner     2
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [197 rows x 7 columns]

# %% [markdown]
# #### Display first 10 rows where day is Sunday and total_bill is more than 5

# %%
df[(df['day'] == 'Sun') & (df['total_bill'] > 5)].head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %% [markdown]
# #### Display first 3 columns of last 10 rows

# %%
df.iloc[-10:,:3]
# Out:
#      total_bill   tip     sex
# 234       15.53  3.00    Male
# 235       10.07  1.25    Male
# 236       12.60  1.00    Male
# 237       32.83  1.17    Male
# 238       35.83  4.67  Female
# 239       29.03  5.92    Male
# 240       27.18  2.00  Female
# 241       22.67  2.00    Male
# 242       17.82  1.75    Male
# 243       18.78  3.00  Female

# %% [markdown]
# #### Display columns from sex to time for first 20 rows

# %%
df.loc[:20,'sex':'time']
# Out:
#        sex smoker  day    time
# 0   Female     No  Sun  Dinner
# 1     Male     No  Sun  Dinner
# 2     Male     No  Sun  Dinner
# 3     Male     No  Sun  Dinner
# 4   Female     No  Sun  Dinner
# 5     Male     No  Sun  Dinner
# 6     Male     No  Sun  Dinner
# 7     Male     No  Sun  Dinner
# 8     Male     No  Sun  Dinner
# 9     Male     No  Sun  Dinner
# 10    Male     No  Sun  Dinner
# 11  Female     No  Sun  Dinner
# 12    Male     No  Sun  Dinner
# 13    Male     No  Sun  Dinner
# 14  Female     No  Sun  Dinner
# 15    Male     No  Sun  Dinner
# 16  Female     No  Sun  Dinner
# 17    Male     No  Sun  Dinner
# 18  Female     No  Sun  Dinner
# 19    Male     No  Sat  Dinner
# 20    Male     No  Sat  Dinner

# %% [markdown]
# #### Display day, total_bill and % of tip amount to total_bill where day is Sunday

# %%
df['tip_per'] = df['tip'] / df['total_bill'] * 100
df[df['day'] == 'Sun'][['day','total_bill','tip_per']]
# Out:
#      day  total_bill    tip_per
# 0    Sun       16.99   5.944673
# 1    Sun       10.34  16.054159
# 2    Sun       21.01  16.658734
# 3    Sun       23.68  13.978041
# 4    Sun       24.59  14.680765
# 5    Sun       25.29  18.623962
# 6    Sun        8.77  22.805017
# 7    Sun       26.88  11.607143
# 8    Sun       15.04  13.031915
# 9    Sun       14.78  21.853857
# 10   Sun       10.27  16.650438
# 11   Sun       35.26  14.180374
# 12   Sun       15.42  10.181582
# 13   Sun       18.43  16.277808
# 14   Sun       14.83  20.364127
# 15   Sun       21.58  18.164968
# 16   Sun       10.33  16.166505
# 17   Sun       16.29  22.774708
# 18   Sun       16.97  20.624632
# 41   Sun       17.46  14.547537
# 42   Sun       13.94  21.951220
# 43   Sun        9.68  13.636364
# 44   Sun       30.40  18.421053
# 45   Sun       18.29  16.402406
# 46   Sun       22.23  22.492128
# 47   Sun       32.40  18.518519
# 48   Sun       28.55   7.180385
# 49   Sun       18.04  16.629712
# 50   Sun       12.54  19.936204
# 51   Sun       10.29  25.267250
# ..   ...         ...        ...
# 157  Sun       25.00  15.000000
# 158  Sun       13.39  19.492158
# 159  Sun       16.49  12.128563
# 160  Sun       21.50  16.279070
# 161  Sun       12.66  19.747235
# 162  Sun       16.21  12.338063
# 163  Sun       13.81  14.482259
# 164  Sun       17.51  17.133067
# 165  Sun       24.52  14.192496
# 166  Sun       20.76  10.789981
# 167  Sun       31.71  14.191107
# 172  Sun        7.25  71.034483
# 173  Sun       31.85   9.984301
# 174  Sun       16.82  23.781213
# 175  Sun       32.90   9.452888
# 176  Sun       17.89  11.179430
# 177  Sun       14.48  13.812155
# 178  Sun        9.60  41.666667
# 179  Sun       34.63  10.251227
# 180  Sun       34.65  10.620491
# 181  Sun       23.33  24.217745
# 182  Sun       45.35   7.717751
# 183  Sun       23.17  28.053517
# 184  Sun       40.55   7.398274
# 185  Sun       20.69  24.166264
# 186  Sun       20.90  16.746411
# 187  Sun       30.46   6.565988
# 188  Sun       18.15  19.283747
# 189  Sun       23.10  17.316017
# 190  Sun       15.69   9.560229
#
# [76 rows x 3 columns]

# %%
df.drop(['tip_per'],axis=1,inplace=True)

# %% [markdown]
# #### Display rows where total_bill is more than 10 and tip amount is less than 2

# %%
df[(df['total_bill'] > 10) & (df['tip'] < 2)]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 16        10.33  1.67  Female     No   Sun  Dinner     3
# 57        26.41  1.50  Female     No   Sat  Dinner     2
# 58        11.24  1.76    Male    Yes   Sat  Dinner     2
# 62        11.02  1.98    Male    Yes   Sat  Dinner     2
# 70        12.02  1.97    Male     No   Sat  Dinner     2
# 75        10.51  1.25    Male     No   Sat  Dinner     2
# 82        10.07  1.83  Female     No  Thur   Lunch     1
# 97        12.03  1.50    Male    Yes   Fri  Dinner     2
# 99        12.46  1.50    Male     No   Fri  Dinner     2
# 105       15.36  1.64    Male    Yes   Sat  Dinner     2
# 117       10.65  1.50  Female     No  Thur   Lunch     2
# 118       12.43  1.80  Female     No  Thur   Lunch     2
# 121       13.42  1.68  Female     No  Thur   Lunch     2
# 130       19.08  1.50    Male     No  Thur   Lunch     2
# 132       11.17  1.50  Female     No  Thur   Lunch     2
# 146       18.64  1.36  Female     No  Thur   Lunch     3
# 147       11.87  1.63  Female     No  Thur   Lunch     2
# 168       10.59  1.61  Female    Yes   Sat  Dinner     2
# 190       15.69  1.50    Male    Yes   Sun  Dinner     2
# 215       12.90  1.10  Female    Yes   Sat  Dinner     2
# 217       11.59  1.50    Male    Yes   Sat  Dinner     2
# 224       13.42  1.58    Male    Yes   Fri   Lunch     2
# 233       10.77  1.47    Male     No   Sat  Dinner     2
# 235       10.07  1.25    Male     No   Sat  Dinner     2
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2

# %% [markdown]
# #### Display total_bill, tip and day for 10 randomly selected rows

# %%
df[['total_bill','tip','day']].sample(n=10)
# Out:
#      total_bill   tip   day
# 146       18.64  1.36  Thur
# 14        14.83  3.02   Sun
# 50        12.54  2.50   Sun
# 178        9.60  4.00   Sun
# 185       20.69  5.00   Sun
# 61        13.81  2.00   Sat
# 123       15.95  2.00  Thur
# 70        12.02  1.97   Sat
# 54        25.56  4.34   Sun
# 120       11.69  2.31  Thur

# %% [markdown]
# #### Display data from columns where name contains letter a

# %%
for c in df.columns[df.columns.str.contains('a')]:
    print(c)
# Out:
# total_bill
# day

# %% [markdown]
# #### Display rows by sorting them by tip amount in desending order

# %%
df.sort_values(by='tip', ascending=False)
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 23        39.42   7.58    Male     No   Sat  Dinner     4
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 141       34.30   6.70    Male     No  Thur   Lunch     6
# 214       28.17   6.50  Female    Yes   Sat  Dinner     3
# 183       23.17   6.50    Male    Yes   Sun  Dinner     4
# 47        32.40   6.00    Male     No   Sun  Dinner     4
# 239       29.03   5.92    Male     No   Sat  Dinner     3
# 88        24.71   5.85    Male     No  Thur   Lunch     2
# 181       23.33   5.65    Male    Yes   Sun  Dinner     2
# 44        30.40   5.60    Male     No   Sun  Dinner     4
# 52        34.81   5.20  Female     No   Sun  Dinner     4
# 85        34.83   5.17  Female     No  Thur   Lunch     4
# 211       25.89   5.16    Male    Yes   Sat  Dinner     4
# 172        7.25   5.15    Male    Yes   Sun  Dinner     2
# 155       29.85   5.14  Female     No   Sun  Dinner     5
# 116       29.93   5.07    Male     No   Sun  Dinner     4
# 39        31.27   5.00    Male     No   Sat  Dinner     3
# 142       41.19   5.00    Male     No  Thur   Lunch     5
# 46        22.23   5.00    Male     No   Sun  Dinner     2
# 185       20.69   5.00    Male     No   Sun  Dinner     5
# 83        32.68   5.00    Male    Yes  Thur   Lunch     2
# 156       48.17   5.00    Male     No   Sun  Dinner     6
# 197       43.11   5.00  Female    Yes  Thur   Lunch     4
# 11        35.26   5.00  Female     No   Sun  Dinner     4
# 143       27.05   5.00  Female     No  Thur   Lunch     6
# 73        25.28   5.00  Female    Yes   Sat  Dinner     2
# 95        40.17   4.73    Male    Yes   Fri  Dinner     4
# 5         25.29   4.71    Male     No   Sun  Dinner     4
# ..          ...    ...     ...    ...   ...     ...   ...
# 168       10.59   1.61  Female    Yes   Sat  Dinner     2
# 224       13.42   1.58    Male    Yes   Fri   Lunch     2
# 12        15.42   1.57    Male     No   Sun  Dinner     2
# 53         9.94   1.56    Male     No   Sun  Dinner     2
# 97        12.03   1.50    Male    Yes   Fri  Dinner     2
# 99        12.46   1.50    Male     No   Fri  Dinner     2
# 190       15.69   1.50    Male    Yes   Sun  Dinner     2
# 117       10.65   1.50  Female     No  Thur   Lunch     2
# 132       11.17   1.50  Female     No  Thur   Lunch     2
# 57        26.41   1.50  Female     No   Sat  Dinner     2
# 217       11.59   1.50    Male    Yes   Sat  Dinner     2
# 130       19.08   1.50    Male     No  Thur   Lunch     2
# 145        8.35   1.50  Female     No  Thur   Lunch     2
# 126        8.52   1.48    Male     No  Thur   Lunch     2
# 233       10.77   1.47    Male     No   Sat  Dinner     2
# 30         9.55   1.45    Male     No   Sat  Dinner     2
# 195        7.56   1.44    Male     No  Thur   Lunch     2
# 218        7.74   1.44    Male    Yes   Sat  Dinner     2
# 146       18.64   1.36  Female     No  Thur   Lunch     3
# 43         9.68   1.32    Male     No   Sun  Dinner     2
# 75        10.51   1.25    Male     No   Sat  Dinner     2
# 135        8.51   1.25  Female     No  Thur   Lunch     2
# 235       10.07   1.25    Male     No   Sat  Dinner     2
# 237       32.83   1.17    Male    Yes   Sat  Dinner     2
# 215       12.90   1.10  Female    Yes   Sat  Dinner     2
# 0         16.99   1.01  Female     No   Sun  Dinner     2
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2
# 111        7.25   1.00  Female     No   Sat  Dinner     1
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# #### Display day and sex in uppercase

# %%
df[['day','sex']].applymap(lambda s:s.upper())
# Out:
#       day     sex
# 0     SUN  FEMALE
# 1     SUN    MALE
# 2     SUN    MALE
# 3     SUN    MALE
# 4     SUN  FEMALE
# 5     SUN    MALE
# 6     SUN    MALE
# 7     SUN    MALE
# 8     SUN    MALE
# 9     SUN    MALE
# 10    SUN    MALE
# 11    SUN  FEMALE
# 12    SUN    MALE
# 13    SUN    MALE
# 14    SUN  FEMALE
# 15    SUN    MALE
# 16    SUN  FEMALE
# 17    SUN    MALE
# 18    SUN  FEMALE
# 19    SAT    MALE
# 20    SAT    MALE
# 21    SAT  FEMALE
# 22    SAT  FEMALE
# 23    SAT    MALE
# 24    SAT    MALE
# 25    SAT    MALE
# 26    SAT    MALE
# 27    SAT    MALE
# 28    SAT    MALE
# 29    SAT  FEMALE
# ..    ...     ...
# 214   SAT  FEMALE
# 215   SAT  FEMALE
# 216   SAT    MALE
# 217   SAT    MALE
# 218   SAT    MALE
# 219   SAT  FEMALE
# 220   FRI    MALE
# 221   FRI  FEMALE
# 222   FRI    MALE
# 223   FRI  FEMALE
# 224   FRI    MALE
# 225   FRI  FEMALE
# 226   FRI  FEMALE
# 227   SAT    MALE
# 228   SAT    MALE
# 229   SAT  FEMALE
# 230   SAT    MALE
# 231   SAT    MALE
# 232   SAT    MALE
# 233   SAT    MALE
# 234   SAT    MALE
# 235   SAT    MALE
# 236   SAT    MALE
# 237   SAT    MALE
# 238   SAT  FEMALE
# 239   SAT    MALE
# 240   SAT  FEMALE
# 241   SAT    MALE
# 242   SAT    MALE
# 243  THUR  FEMALE
#
# [244 rows x 2 columns]

# %% [markdown]
# #### Display rows where day starts with S

# %%
df[df['day'].str.startswith('S')]
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 0         16.99  1.01  Female     No  Sun  Dinner     2
# 1         10.34  1.66    Male     No  Sun  Dinner     3
# 2         21.01  3.50    Male     No  Sun  Dinner     3
# 3         23.68  3.31    Male     No  Sun  Dinner     2
# 4         24.59  3.61  Female     No  Sun  Dinner     4
# 5         25.29  4.71    Male     No  Sun  Dinner     4
# 6          8.77  2.00    Male     No  Sun  Dinner     2
# 7         26.88  3.12    Male     No  Sun  Dinner     4
# 8         15.04  1.96    Male     No  Sun  Dinner     2
# 9         14.78  3.23    Male     No  Sun  Dinner     2
# 10        10.27  1.71    Male     No  Sun  Dinner     2
# 11        35.26  5.00  Female     No  Sun  Dinner     4
# 12        15.42  1.57    Male     No  Sun  Dinner     2
# 13        18.43  3.00    Male     No  Sun  Dinner     4
# 14        14.83  3.02  Female     No  Sun  Dinner     2
# 15        21.58  3.92    Male     No  Sun  Dinner     2
# 16        10.33  1.67  Female     No  Sun  Dinner     3
# 17        16.29  3.71    Male     No  Sun  Dinner     3
# 18        16.97  3.50  Female     No  Sun  Dinner     3
# 19        20.65  3.35    Male     No  Sat  Dinner     3
# 20        17.92  4.08    Male     No  Sat  Dinner     2
# 21        20.29  2.75  Female     No  Sat  Dinner     2
# 22        15.77  2.23  Female     No  Sat  Dinner     2
# 23        39.42  7.58    Male     No  Sat  Dinner     4
# 24        19.82  3.18    Male     No  Sat  Dinner     2
# 25        17.81  2.34    Male     No  Sat  Dinner     4
# 26        13.37  2.00    Male     No  Sat  Dinner     2
# 27        12.69  2.00    Male     No  Sat  Dinner     2
# 28        21.70  4.30    Male     No  Sat  Dinner     2
# 29        19.65  3.00  Female     No  Sat  Dinner     2
# ..          ...   ...     ...    ...  ...     ...   ...
# 206       26.59  3.41    Male    Yes  Sat  Dinner     3
# 207       38.73  3.00    Male    Yes  Sat  Dinner     4
# 208       24.27  2.03    Male    Yes  Sat  Dinner     2
# 209       12.76  2.23  Female    Yes  Sat  Dinner     2
# 210       30.06  2.00    Male    Yes  Sat  Dinner     3
# 211       25.89  5.16    Male    Yes  Sat  Dinner     4
# 212       48.33  9.00    Male     No  Sat  Dinner     4
# 213       13.27  2.50  Female    Yes  Sat  Dinner     2
# 214       28.17  6.50  Female    Yes  Sat  Dinner     3
# 215       12.90  1.10  Female    Yes  Sat  Dinner     2
# 216       28.15  3.00    Male    Yes  Sat  Dinner     5
# 217       11.59  1.50    Male    Yes  Sat  Dinner     2
# 218        7.74  1.44    Male    Yes  Sat  Dinner     2
# 219       30.14  3.09  Female    Yes  Sat  Dinner     4
# 227       20.45  3.00    Male     No  Sat  Dinner     4
# 228       13.28  2.72    Male     No  Sat  Dinner     2
# 229       22.12  2.88  Female    Yes  Sat  Dinner     2
# 230       24.01  2.00    Male    Yes  Sat  Dinner     4
# 231       15.69  3.00    Male    Yes  Sat  Dinner     3
# 232       11.61  3.39    Male     No  Sat  Dinner     2
# 233       10.77  1.47    Male     No  Sat  Dinner     2
# 234       15.53  3.00    Male    Yes  Sat  Dinner     2
# 235       10.07  1.25    Male     No  Sat  Dinner     2
# 236       12.60  1.00    Male    Yes  Sat  Dinner     2
# 237       32.83  1.17    Male    Yes  Sat  Dinner     2
# 238       35.83  4.67  Female     No  Sat  Dinner     3
# 239       29.03  5.92    Male     No  Sat  Dinner     3
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2
# 242       17.82  1.75    Male     No  Sat  Dinner     2
#
# [163 rows x 7 columns]

# %% [markdown]
# #### Display message low if total_bill is less than 10, medium if less than 20 otherwise high

# %%
def get_message(v):
    if v['total_bill'] < 10:
        return 'Low'
    elif v['total_bill'] < 20:
        return 'Medium'
    else:
        return 'High'

df['message'] = df.apply(get_message,axis=1)
df
# Out:
#      total_bill   tip     sex smoker   day    time  size message
# 0         16.99  1.01  Female     No   Sun  Dinner     2  Medium
# 1         10.34  1.66    Male     No   Sun  Dinner     3  Medium
# 2         21.01  3.50    Male     No   Sun  Dinner     3    High
# 3         23.68  3.31    Male     No   Sun  Dinner     2    High
# 4         24.59  3.61  Female     No   Sun  Dinner     4    High
# 5         25.29  4.71    Male     No   Sun  Dinner     4    High
# 6          8.77  2.00    Male     No   Sun  Dinner     2     Low
# 7         26.88  3.12    Male     No   Sun  Dinner     4    High
# 8         15.04  1.96    Male     No   Sun  Dinner     2  Medium
# 9         14.78  3.23    Male     No   Sun  Dinner     2  Medium
# 10        10.27  1.71    Male     No   Sun  Dinner     2  Medium
# 11        35.26  5.00  Female     No   Sun  Dinner     4    High
# 12        15.42  1.57    Male     No   Sun  Dinner     2  Medium
# 13        18.43  3.00    Male     No   Sun  Dinner     4  Medium
# 14        14.83  3.02  Female     No   Sun  Dinner     2  Medium
# 15        21.58  3.92    Male     No   Sun  Dinner     2    High
# 16        10.33  1.67  Female     No   Sun  Dinner     3  Medium
# 17        16.29  3.71    Male     No   Sun  Dinner     3  Medium
# 18        16.97  3.50  Female     No   Sun  Dinner     3  Medium
# 19        20.65  3.35    Male     No   Sat  Dinner     3    High
# 20        17.92  4.08    Male     No   Sat  Dinner     2  Medium
# 21        20.29  2.75  Female     No   Sat  Dinner     2    High
# 22        15.77  2.23  Female     No   Sat  Dinner     2  Medium
# 23        39.42  7.58    Male     No   Sat  Dinner     4    High
# 24        19.82  3.18    Male     No   Sat  Dinner     2  Medium
# 25        17.81  2.34    Male     No   Sat  Dinner     4  Medium
# 26        13.37  2.00    Male     No   Sat  Dinner     2  Medium
# 27        12.69  2.00    Male     No   Sat  Dinner     2  Medium
# 28        21.70  4.30    Male     No   Sat  Dinner     2    High
# 29        19.65  3.00  Female     No   Sat  Dinner     2  Medium
# ..          ...   ...     ...    ...   ...     ...   ...     ...
# 214       28.17  6.50  Female    Yes   Sat  Dinner     3    High
# 215       12.90  1.10  Female    Yes   Sat  Dinner     2  Medium
# 216       28.15  3.00    Male    Yes   Sat  Dinner     5    High
# 217       11.59  1.50    Male    Yes   Sat  Dinner     2  Medium
# 218        7.74  1.44    Male    Yes   Sat  Dinner     2     Low
# 219       30.14  3.09  Female    Yes   Sat  Dinner     4    High
# 220       12.16  2.20    Male    Yes   Fri   Lunch     2  Medium
# 221       13.42  3.48  Female    Yes   Fri   Lunch     2  Medium
# 222        8.58  1.92    Male    Yes   Fri   Lunch     1     Low
# 223       15.98  3.00  Female     No   Fri   Lunch     3  Medium
# 224       13.42  1.58    Male    Yes   Fri   Lunch     2  Medium
# 225       16.27  2.50  Female    Yes   Fri   Lunch     2  Medium
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2  Medium
# 227       20.45  3.00    Male     No   Sat  Dinner     4    High
# 228       13.28  2.72    Male     No   Sat  Dinner     2  Medium
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2    High
# 230       24.01  2.00    Male    Yes   Sat  Dinner     4    High
# 231       15.69  3.00    Male    Yes   Sat  Dinner     3  Medium
# 232       11.61  3.39    Male     No   Sat  Dinner     2  Medium
# 233       10.77  1.47    Male     No   Sat  Dinner     2  Medium
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2  Medium
# 235       10.07  1.25    Male     No   Sat  Dinner     2  Medium
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2  Medium
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2    High
# 238       35.83  4.67  Female     No   Sat  Dinner     3    High
# 239       29.03  5.92    Male     No   Sat  Dinner     3    High
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2    High
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2    High
# 242       17.82  1.75    Male     No   Sat  Dinner     2  Medium
# 243       18.78  3.00  Female     No  Thur  Dinner     2  Medium
#
# [244 rows x 8 columns]

# %%
# Other way is to use pd.cut() for binning 
pd.cut(df['total_bill'], bins=[0,10,20,100], labels=['Low','Medium','High'])
# Out:
# 0      Medium
# 1      Medium
# 2        High
# 3        High
# 4        High
#         ...
# 239      High
# 240      High
# 241      High
# 242    Medium
# 243    Medium
# Name: total_bill, Length: 244, dtype: category
# Categories (3, object): [Low < Medium < High]

# %% [markdown]
# #### Display how many null values we have in each column

# %%
df.isna().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# message       0
# dtype: int64

# %% [markdown]
# #### Display top 5 tip amounts for smokers

# %%
df[df['smoker'] == 'Yes'].nlargest(5,'tip')
# Out:
#      total_bill    tip     sex smoker  day    time  size message
# 170       50.81  10.00    Male    Yes  Sat  Dinner     3    High
# 183       23.17   6.50    Male    Yes  Sun  Dinner     4    High
# 214       28.17   6.50  Female    Yes  Sat  Dinner     3    High
# 181       23.33   5.65    Male    Yes  Sun  Dinner     2    High
# 211       25.89   5.16    Male    Yes  Sat  Dinner     4    High

# %% [markdown]
# #### Display total_bill and tip amounts rounded

# %%
df[['total_bill','tip']].applymap(lambda v:round(v))
# Out:
#      total_bill  tip
# 0            17    1
# 1            10    2
# 2            21    4
# 3            24    3
# 4            25    4
# 5            25    5
# 6             9    2
# 7            27    3
# 8            15    2
# 9            15    3
# 10           10    2
# 11           35    5
# 12           15    2
# 13           18    3
# 14           15    3
# 15           22    4
# 16           10    2
# 17           16    4
# 18           17    4
# 19           21    3
# 20           18    4
# 21           20    3
# 22           16    2
# 23           39    8
# 24           20    3
# 25           18    2
# 26           13    2
# 27           13    2
# 28           22    4
# 29           20    3
# ..          ...  ...
# 214          28    6
# 215          13    1
# 216          28    3
# 217          12    2
# 218           8    1
# 219          30    3
# 220          12    2
# 221          13    3
# 222           9    2
# 223          16    3
# 224          13    2
# 225          16    2
# 226          10    2
# 227          20    3
# 228          13    3
# 229          22    3
# 230          24    2
# 231          16    3
# 232          12    3
# 233          11    1
# 234          16    3
# 235          10    1
# 236          13    1
# 237          33    1
# 238          36    5
# 239          29    6
# 240          27    2
# 241          23    2
# 242          18    2
# 243          19    3
#
# [244 rows x 2 columns]

# %% [markdown]
# <h2 style='color:red'>Adding and deleting rows and columns</h2>

# %% [markdown]
# #### Add a new column called tip_per to store % of tip to total_bill

# %%
df['tip_per'] = df['tip'] / df['total_bill'] * 100
df
# Out:
#      total_bill   tip     sex smoker   day    time  size message    tip_per
# 0         16.99  1.01  Female     No   Sun  Dinner     2  Medium   5.944673
# 1         10.34  1.66    Male     No   Sun  Dinner     3  Medium  16.054159
# 2         21.01  3.50    Male     No   Sun  Dinner     3    High  16.658734
# 3         23.68  3.31    Male     No   Sun  Dinner     2    High  13.978041
# 4         24.59  3.61  Female     No   Sun  Dinner     4    High  14.680765
# 5         25.29  4.71    Male     No   Sun  Dinner     4    High  18.623962
# 6          8.77  2.00    Male     No   Sun  Dinner     2     Low  22.805017
# 7         26.88  3.12    Male     No   Sun  Dinner     4    High  11.607143
# 8         15.04  1.96    Male     No   Sun  Dinner     2  Medium  13.031915
# 9         14.78  3.23    Male     No   Sun  Dinner     2  Medium  21.853857
# 10        10.27  1.71    Male     No   Sun  Dinner     2  Medium  16.650438
# 11        35.26  5.00  Female     No   Sun  Dinner     4    High  14.180374
# 12        15.42  1.57    Male     No   Sun  Dinner     2  Medium  10.181582
# 13        18.43  3.00    Male     No   Sun  Dinner     4  Medium  16.277808
# 14        14.83  3.02  Female     No   Sun  Dinner     2  Medium  20.364127
# 15        21.58  3.92    Male     No   Sun  Dinner     2    High  18.164968
# 16        10.33  1.67  Female     No   Sun  Dinner     3  Medium  16.166505
# 17        16.29  3.71    Male     No   Sun  Dinner     3  Medium  22.774708
# 18        16.97  3.50  Female     No   Sun  Dinner     3  Medium  20.624632
# 19        20.65  3.35    Male     No   Sat  Dinner     3    High  16.222760
# 20        17.92  4.08    Male     No   Sat  Dinner     2  Medium  22.767857
# 21        20.29  2.75  Female     No   Sat  Dinner     2    High  13.553475
# 22        15.77  2.23  Female     No   Sat  Dinner     2  Medium  14.140774
# 23        39.42  7.58    Male     No   Sat  Dinner     4    High  19.228818
# 24        19.82  3.18    Male     No   Sat  Dinner     2  Medium  16.044400
# 25        17.81  2.34    Male     No   Sat  Dinner     4  Medium  13.138686
# 26        13.37  2.00    Male     No   Sat  Dinner     2  Medium  14.958863
# 27        12.69  2.00    Male     No   Sat  Dinner     2  Medium  15.760441
# 28        21.70  4.30    Male     No   Sat  Dinner     2    High  19.815668
# 29        19.65  3.00  Female     No   Sat  Dinner     2  Medium  15.267176
# ..          ...   ...     ...    ...   ...     ...   ...     ...        ...
# 214       28.17  6.50  Female    Yes   Sat  Dinner     3    High  23.074192
# 215       12.90  1.10  Female    Yes   Sat  Dinner     2  Medium   8.527132
# 216       28.15  3.00    Male    Yes   Sat  Dinner     5    High  10.657194
# 217       11.59  1.50    Male    Yes   Sat  Dinner     2  Medium  12.942192
# 218        7.74  1.44    Male    Yes   Sat  Dinner     2     Low  18.604651
# 219       30.14  3.09  Female    Yes   Sat  Dinner     4    High  10.252157
# 220       12.16  2.20    Male    Yes   Fri   Lunch     2  Medium  18.092105
# 221       13.42  3.48  Female    Yes   Fri   Lunch     2  Medium  25.931446
# 222        8.58  1.92    Male    Yes   Fri   Lunch     1     Low  22.377622
# 223       15.98  3.00  Female     No   Fri   Lunch     3  Medium  18.773467
# 224       13.42  1.58    Male    Yes   Fri   Lunch     2  Medium  11.773472
# 225       16.27  2.50  Female    Yes   Fri   Lunch     2  Medium  15.365704
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2  Medium  19.821606
# 227       20.45  3.00    Male     No   Sat  Dinner     4    High  14.669927
# 228       13.28  2.72    Male     No   Sat  Dinner     2  Medium  20.481928
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2    High  13.019892
# 230       24.01  2.00    Male    Yes   Sat  Dinner     4    High   8.329863
# 231       15.69  3.00    Male    Yes   Sat  Dinner     3  Medium  19.120459
# 232       11.61  3.39    Male     No   Sat  Dinner     2  Medium  29.198966
# 233       10.77  1.47    Male     No   Sat  Dinner     2  Medium  13.649025
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2  Medium  19.317450
# 235       10.07  1.25    Male     No   Sat  Dinner     2  Medium  12.413108
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2  Medium   7.936508
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2    High   3.563814
# 238       35.83  4.67  Female     No   Sat  Dinner     3    High  13.033771
# 239       29.03  5.92    Male     No   Sat  Dinner     3    High  20.392697
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2    High   7.358352
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2    High   8.822232
# 242       17.82  1.75    Male     No   Sat  Dinner     2  Medium   9.820426
# 243       18.78  3.00  Female     No  Thur  Dinner     2  Medium  15.974441
#
# [244 rows x 9 columns]

# %% [markdown]
# #### Add a new row at the end of dataframe

# %%
df = df.append({'total_bill':15,'tip':2,'sex':'Male','smoker':'No','day':'Sat','time':'Dinner','size':4},ignore_index=True)

# %%
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size message    tip_per
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2    High   7.358352
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2    High   8.822232
# 242       17.82  1.75    Male     No   Sat  Dinner     2  Medium   9.820426
# 243       18.78  3.00  Female     No  Thur  Dinner     2  Medium  15.974441
# 244       15.00  2.00    Male     No   Sat  Dinner     4     NaN        NaN

# %% [markdown]
# #### Return dataframe after deleting rows with index 10 and 20

# %%
df.drop([10,20])
# Out:
#      total_bill   tip     sex smoker   day    time  size message    tip_per
# 0         16.99  1.01  Female     No   Sun  Dinner     2  Medium   5.944673
# 1         10.34  1.66    Male     No   Sun  Dinner     3  Medium  16.054159
# 2         21.01  3.50    Male     No   Sun  Dinner     3    High  16.658734
# 3         23.68  3.31    Male     No   Sun  Dinner     2    High  13.978041
# 4         24.59  3.61  Female     No   Sun  Dinner     4    High  14.680765
# 5         25.29  4.71    Male     No   Sun  Dinner     4    High  18.623962
# 6          8.77  2.00    Male     No   Sun  Dinner     2     Low  22.805017
# 7         26.88  3.12    Male     No   Sun  Dinner     4    High  11.607143
# 8         15.04  1.96    Male     No   Sun  Dinner     2  Medium  13.031915
# 9         14.78  3.23    Male     No   Sun  Dinner     2  Medium  21.853857
# 11        35.26  5.00  Female     No   Sun  Dinner     4    High  14.180374
# 12        15.42  1.57    Male     No   Sun  Dinner     2  Medium  10.181582
# 13        18.43  3.00    Male     No   Sun  Dinner     4  Medium  16.277808
# 14        14.83  3.02  Female     No   Sun  Dinner     2  Medium  20.364127
# 15        21.58  3.92    Male     No   Sun  Dinner     2    High  18.164968
# 16        10.33  1.67  Female     No   Sun  Dinner     3  Medium  16.166505
# 17        16.29  3.71    Male     No   Sun  Dinner     3  Medium  22.774708
# 18        16.97  3.50  Female     No   Sun  Dinner     3  Medium  20.624632
# 19        20.65  3.35    Male     No   Sat  Dinner     3    High  16.222760
# 21        20.29  2.75  Female     No   Sat  Dinner     2    High  13.553475
# 22        15.77  2.23  Female     No   Sat  Dinner     2  Medium  14.140774
# 23        39.42  7.58    Male     No   Sat  Dinner     4    High  19.228818
# 24        19.82  3.18    Male     No   Sat  Dinner     2  Medium  16.044400
# 25        17.81  2.34    Male     No   Sat  Dinner     4  Medium  13.138686
# 26        13.37  2.00    Male     No   Sat  Dinner     2  Medium  14.958863
# 27        12.69  2.00    Male     No   Sat  Dinner     2  Medium  15.760441
# 28        21.70  4.30    Male     No   Sat  Dinner     2    High  19.815668
# 29        19.65  3.00  Female     No   Sat  Dinner     2  Medium  15.267176
# 30         9.55  1.45    Male     No   Sat  Dinner     2     Low  15.183246
# 31        18.35  2.50    Male     No   Sat  Dinner     4  Medium  13.623978
# ..          ...   ...     ...    ...   ...     ...   ...     ...        ...
# 215       12.90  1.10  Female    Yes   Sat  Dinner     2  Medium   8.527132
# 216       28.15  3.00    Male    Yes   Sat  Dinner     5    High  10.657194
# 217       11.59  1.50    Male    Yes   Sat  Dinner     2  Medium  12.942192
# 218        7.74  1.44    Male    Yes   Sat  Dinner     2     Low  18.604651
# 219       30.14  3.09  Female    Yes   Sat  Dinner     4    High  10.252157
# 220       12.16  2.20    Male    Yes   Fri   Lunch     2  Medium  18.092105
# 221       13.42  3.48  Female    Yes   Fri   Lunch     2  Medium  25.931446
# 222        8.58  1.92    Male    Yes   Fri   Lunch     1     Low  22.377622
# 223       15.98  3.00  Female     No   Fri   Lunch     3  Medium  18.773467
# 224       13.42  1.58    Male    Yes   Fri   Lunch     2  Medium  11.773472
# 225       16.27  2.50  Female    Yes   Fri   Lunch     2  Medium  15.365704
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2  Medium  19.821606
# 227       20.45  3.00    Male     No   Sat  Dinner     4    High  14.669927
# 228       13.28  2.72    Male     No   Sat  Dinner     2  Medium  20.481928
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2    High  13.019892
# 230       24.01  2.00    Male    Yes   Sat  Dinner     4    High   8.329863
# 231       15.69  3.00    Male    Yes   Sat  Dinner     3  Medium  19.120459
# 232       11.61  3.39    Male     No   Sat  Dinner     2  Medium  29.198966
# 233       10.77  1.47    Male     No   Sat  Dinner     2  Medium  13.649025
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2  Medium  19.317450
# 235       10.07  1.25    Male     No   Sat  Dinner     2  Medium  12.413108
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2  Medium   7.936508
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2    High   3.563814
# 238       35.83  4.67  Female     No   Sat  Dinner     3    High  13.033771
# 239       29.03  5.92    Male     No   Sat  Dinner     3    High  20.392697
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2    High   7.358352
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2    High   8.822232
# 242       17.82  1.75    Male     No   Sat  Dinner     2  Medium   9.820426
# 243       18.78  3.00  Female     No  Thur  Dinner     2  Medium  15.974441
# 244       15.00  2.00    Male     No   Sat  Dinner     4     NaN        NaN
#
# [243 rows x 9 columns]

# %% [markdown]
# #### Return dataframe after deleting columns smoker and time

# %%
df.drop(['smoker','time'],axis=1)
# Out:
#      total_bill   tip     sex   day  size message    tip_per
# 0         16.99  1.01  Female   Sun     2  Medium   5.944673
# 1         10.34  1.66    Male   Sun     3  Medium  16.054159
# 2         21.01  3.50    Male   Sun     3    High  16.658734
# 3         23.68  3.31    Male   Sun     2    High  13.978041
# 4         24.59  3.61  Female   Sun     4    High  14.680765
# 5         25.29  4.71    Male   Sun     4    High  18.623962
# 6          8.77  2.00    Male   Sun     2     Low  22.805017
# 7         26.88  3.12    Male   Sun     4    High  11.607143
# 8         15.04  1.96    Male   Sun     2  Medium  13.031915
# 9         14.78  3.23    Male   Sun     2  Medium  21.853857
# 10        10.27  1.71    Male   Sun     2  Medium  16.650438
# 11        35.26  5.00  Female   Sun     4    High  14.180374
# 12        15.42  1.57    Male   Sun     2  Medium  10.181582
# 13        18.43  3.00    Male   Sun     4  Medium  16.277808
# 14        14.83  3.02  Female   Sun     2  Medium  20.364127
# 15        21.58  3.92    Male   Sun     2    High  18.164968
# 16        10.33  1.67  Female   Sun     3  Medium  16.166505
# 17        16.29  3.71    Male   Sun     3  Medium  22.774708
# 18        16.97  3.50  Female   Sun     3  Medium  20.624632
# 19        20.65  3.35    Male   Sat     3    High  16.222760
# 20        17.92  4.08    Male   Sat     2  Medium  22.767857
# 21        20.29  2.75  Female   Sat     2    High  13.553475
# 22        15.77  2.23  Female   Sat     2  Medium  14.140774
# 23        39.42  7.58    Male   Sat     4    High  19.228818
# 24        19.82  3.18    Male   Sat     2  Medium  16.044400
# 25        17.81  2.34    Male   Sat     4  Medium  13.138686
# 26        13.37  2.00    Male   Sat     2  Medium  14.958863
# 27        12.69  2.00    Male   Sat     2  Medium  15.760441
# 28        21.70  4.30    Male   Sat     2    High  19.815668
# 29        19.65  3.00  Female   Sat     2  Medium  15.267176
# ..          ...   ...     ...   ...   ...     ...        ...
# 215       12.90  1.10  Female   Sat     2  Medium   8.527132
# 216       28.15  3.00    Male   Sat     5    High  10.657194
# 217       11.59  1.50    Male   Sat     2  Medium  12.942192
# 218        7.74  1.44    Male   Sat     2     Low  18.604651
# 219       30.14  3.09  Female   Sat     4    High  10.252157
# 220       12.16  2.20    Male   Fri     2  Medium  18.092105
# 221       13.42  3.48  Female   Fri     2  Medium  25.931446
# 222        8.58  1.92    Male   Fri     1     Low  22.377622
# 223       15.98  3.00  Female   Fri     3  Medium  18.773467
# 224       13.42  1.58    Male   Fri     2  Medium  11.773472
# 225       16.27  2.50  Female   Fri     2  Medium  15.365704
# 226       10.09  2.00  Female   Fri     2  Medium  19.821606
# 227       20.45  3.00    Male   Sat     4    High  14.669927
# 228       13.28  2.72    Male   Sat     2  Medium  20.481928
# 229       22.12  2.88  Female   Sat     2    High  13.019892
# 230       24.01  2.00    Male   Sat     4    High   8.329863
# 231       15.69  3.00    Male   Sat     3  Medium  19.120459
# 232       11.61  3.39    Male   Sat     2  Medium  29.198966
# 233       10.77  1.47    Male   Sat     2  Medium  13.649025
# 234       15.53  3.00    Male   Sat     2  Medium  19.317450
# 235       10.07  1.25    Male   Sat     2  Medium  12.413108
# 236       12.60  1.00    Male   Sat     2  Medium   7.936508
# 237       32.83  1.17    Male   Sat     2    High   3.563814
# 238       35.83  4.67  Female   Sat     3    High  13.033771
# 239       29.03  5.92    Male   Sat     3    High  20.392697
# 240       27.18  2.00  Female   Sat     2    High   7.358352
# 241       22.67  2.00    Male   Sat     2    High   8.822232
# 242       17.82  1.75    Male   Sat     2  Medium   9.820426
# 243       18.78  3.00  Female  Thur     2  Medium  15.974441
# 244       15.00  2.00    Male   Sat     4     NaN        NaN
#
# [245 rows x 7 columns]

# %% [markdown]
# <h2 style='color:red'>Grouping data</h2>

# %% [markdown]
# #### Display average total_bill for each time

# %%
df.groupby('time')['total_bill'].mean()
# Out:
# time
# Dinner    20.764407
# Lunch     17.168676
# Name: total_bill, dtype: float64

# %% [markdown]
# #### Display total tip amount for each day and each sex

# %%
df.groupby(['day','sex'])['tip'].sum()
# Out:
# day   sex
# Fri   Female     25.03
#       Male       26.93
# Sat   Female     78.45
#       Male      183.95
# Sun   Female     60.61
#       Male      186.78
# Thur  Female     82.42
#       Male       89.41
# Name: tip, dtype: float64

# %% [markdown]
# #### Display total bill amount for each size on Sunday

# %%
df[df['day'] == 'Sun'].groupby('size')['total_bill'].sum()
# Out:
# size
# 2    684.84
# 3    332.76
# 4    480.39
# 5     81.00
# 6     48.17
# Name: total_bill, dtype: float64

# %% [markdown]
# #### Display average total_bill for female on Sunday

# %%
df[(df['day'] == 'Sun') & (df['sex'] == 'Female')]['total_bill'].mean()
# Out:
# 19.87222222222222

# %% [markdown]
# #### Display the 10 transactions in which customers were the most generous

# %%
df.nlargest(10,'tip_per')
# Out:
#      total_bill   tip     sex smoker   day    time  size message    tip_per
# 172        7.25  5.15    Male    Yes   Sun  Dinner     2     Low  71.034483
# 178        9.60  4.00  Female    Yes   Sun  Dinner     2     Low  41.666667
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1     Low  32.573290
# 232       11.61  3.39    Male     No   Sat  Dinner     2  Medium  29.198966
# 183       23.17  6.50    Male    Yes   Sun  Dinner     4    High  28.053517
# 109       14.31  4.00  Female    Yes   Sat  Dinner     2  Medium  27.952481
# 149        7.51  2.00    Male     No  Thur   Lunch     2     Low  26.631158
# 93        16.32  4.30  Female    Yes   Fri  Dinner     2  Medium  26.348039
# 221       13.42  3.48  Female    Yes   Fri   Lunch     2  Medium  25.931446
# 51        10.29  2.60  Female     No   Sun  Dinner     2  Medium  25.267250

# %% [markdown]
# #### Find out on which day we had more customers

# %%
day_count = df.day.value_counts()
day_count.sort_values(ascending=False).head(1)
# Out:
# Sat    87
# Name: day, dtype: int64

# %% [markdown]
# #### Display top 3 transactions based on bill amount for each day

# %%
day_group = df.groupby('day')
# First element is group and second one is row in that group
for g,trans in day_group:
    print(g)
    print(trans.sort_values(by='total_bill', ascending=False).head(3))
# Out:
# Fri
#     total_bill   tip   sex smoker  day    time  size message    tip_per
# 95       40.17  4.73  Male    Yes  Fri  Dinner     4    High  11.774956
# 90       28.97  3.00  Male    Yes  Fri  Dinner     2    High  10.355540
# 96       27.28  4.00  Male    Yes  Fri  Dinner     2    High  14.662757
# Sat
#      total_bill    tip   sex smoker  day    time  size message    tip_per
# 170       50.81  10.00  Male    Yes  Sat  Dinner     3    High  19.681165
# 212       48.33   9.00  Male     No  Sat  Dinner     4    High  18.621974
# 59        48.27   6.73  Male     No  Sat  Dinner     4    High  13.942407
# Sun
#      total_bill  tip   sex smoker  day    time  size message    tip_per
# 156       48.17  5.0  Male     No  Sun  Dinner     6    High  10.379905
# 182       45.35  3.5  Male    Yes  Sun  Dinner     3    High   7.717751
# 184       40.55  3.0  Male    Yes  Sun  Dinner     2    High   7.398274
# Thur
#      total_bill   tip     sex smoker   day   time  size message    tip_per
# 197       43.11  5.00  Female    Yes  Thur  Lunch     4    High  11.598237
# 142       41.19  5.00    Male     No  Thur  Lunch     5    High  12.138869
# 85        34.83  5.17  Female     No  Thur  Lunch     4    High  14.843526

# %% [markdown]
# #### Display ratio of each day's total_bill to the total_bill for all days

# %%
total = df['total_bill'].sum()
df.groupby('day')['total_bill'].sum()/total
# Out:
# day
# Fri     0.067292
# Sat     0.370325
# Sun     0.335998
# Thur    0.226385
# Name: total_bill, dtype: float64

# %% [markdown]
# #### Display max and min total_bill for each day

# %%
df.groupby('day')['total_bill'].aggregate(['max','min'])
# Out:
#         max   min
# day
# Thur  43.11  7.51
# Fri   40.17  5.75
# Sat   50.81  3.07
# Sun   48.17  7.25

# %% [markdown]
# #### Display day on the left and sex at the top and display total bill amount at the intersection

# %%
df.pivot_table(index='day',columns='sex',aggfunc=sum,values=['total_bill'])
# Out:
#      total_bill
# sex      Female     Male
# day
# Fri      127.31   198.57
# Sat      551.05  1242.35
# Sun      357.70  1269.46
# Thur     534.89   561.44

# %% [markdown]
# #### Display total number of customers on each day for each time

# %%
df.pivot_table(index='day',columns='time',aggfunc=sum,values=['size'])
# Out:
#        size
# time  Lunch Dinner
# day
# Thur  150.0    2.0
# Fri    14.0   26.0
# Sat     NaN  219.0
# Sun     NaN  216.0

# %% [markdown]
# #### Display day on left, sum and average of bill amount and tip amount for each sex

# %%
df.pivot_table(index='day',columns='sex',aggfunc={'total_bill':['sum','mean'],'tip':['sum','mean']})
# Out:
#            tip                          total_bill
#           mean               sum              mean                 sum
# sex       Male    Female    Male Female       Male     Female     Male  Female
# day
# Thur  2.980333  2.575625   89.41  82.42  18.714667  16.715312   561.44  534.89
# Fri   2.693000  2.781111   26.93  25.03  19.857000  14.145556   198.57  127.31
# Sat   3.083898  2.801786  181.95  78.45  20.802542  19.680357  1227.35  551.05
# Sun   3.220345  3.367222  186.78  60.61  21.887241  19.872222  1269.46  357.70

# %% [markdown]
# <h2 style='color:red'>Manipulating data</h2>

# %% [markdown]
# #### Change Female to f and Male to m in sex column

# %%
df.replace({'sex' : {'Female':'f','Male':'m'}})
# Out:
#      total_bill   tip sex smoker   day    time  size message    tip_per
# 0         16.99  1.01   f     No   Sun  Dinner     2  Medium   5.944673
# 1         10.34  1.66   m     No   Sun  Dinner     3  Medium  16.054159
# 2         21.01  3.50   m     No   Sun  Dinner     3    High  16.658734
# 3         23.68  3.31   m     No   Sun  Dinner     2    High  13.978041
# 4         24.59  3.61   f     No   Sun  Dinner     4    High  14.680765
# 5         25.29  4.71   m     No   Sun  Dinner     4    High  18.623962
# 6          8.77  2.00   m     No   Sun  Dinner     2     Low  22.805017
# 7         26.88  3.12   m     No   Sun  Dinner     4    High  11.607143
# 8         15.04  1.96   m     No   Sun  Dinner     2  Medium  13.031915
# 9         14.78  3.23   m     No   Sun  Dinner     2  Medium  21.853857
# 10        10.27  1.71   m     No   Sun  Dinner     2  Medium  16.650438
# 11        35.26  5.00   f     No   Sun  Dinner     4    High  14.180374
# 12        15.42  1.57   m     No   Sun  Dinner     2  Medium  10.181582
# 13        18.43  3.00   m     No   Sun  Dinner     4  Medium  16.277808
# 14        14.83  3.02   f     No   Sun  Dinner     2  Medium  20.364127
# 15        21.58  3.92   m     No   Sun  Dinner     2    High  18.164968
# 16        10.33  1.67   f     No   Sun  Dinner     3  Medium  16.166505
# 17        16.29  3.71   m     No   Sun  Dinner     3  Medium  22.774708
# 18        16.97  3.50   f     No   Sun  Dinner     3  Medium  20.624632
# 19        20.65  3.35   m     No   Sat  Dinner     3    High  16.222760
# 20        17.92  4.08   m     No   Sat  Dinner     2  Medium  22.767857
# 21        20.29  2.75   f     No   Sat  Dinner     2    High  13.553475
# 22        15.77  2.23   f     No   Sat  Dinner     2  Medium  14.140774
# 23        39.42  7.58   m     No   Sat  Dinner     4    High  19.228818
# 24        19.82  3.18   m     No   Sat  Dinner     2  Medium  16.044400
# 25        17.81  2.34   m     No   Sat  Dinner     4  Medium  13.138686
# 26        13.37  2.00   m     No   Sat  Dinner     2  Medium  14.958863
# 27        12.69  2.00   m     No   Sat  Dinner     2  Medium  15.760441
# 28        21.70  4.30   m     No   Sat  Dinner     2    High  19.815668
# 29        19.65  3.00   f     No   Sat  Dinner     2  Medium  15.267176
# ..          ...   ...  ..    ...   ...     ...   ...     ...        ...
# 215       12.90  1.10   f    Yes   Sat  Dinner     2  Medium   8.527132
# 216       28.15  3.00   m    Yes   Sat  Dinner     5    High  10.657194
# 217       11.59  1.50   m    Yes   Sat  Dinner     2  Medium  12.942192
# 218        7.74  1.44   m    Yes   Sat  Dinner     2     Low  18.604651
# 219       30.14  3.09   f    Yes   Sat  Dinner     4    High  10.252157
# 220       12.16  2.20   m    Yes   Fri   Lunch     2  Medium  18.092105
# 221       13.42  3.48   f    Yes   Fri   Lunch     2  Medium  25.931446
# 222        8.58  1.92   m    Yes   Fri   Lunch     1     Low  22.377622
# 223       15.98  3.00   f     No   Fri   Lunch     3  Medium  18.773467
# 224       13.42  1.58   m    Yes   Fri   Lunch     2  Medium  11.773472
# 225       16.27  2.50   f    Yes   Fri   Lunch     2  Medium  15.365704
# 226       10.09  2.00   f    Yes   Fri   Lunch     2  Medium  19.821606
# 227       20.45  3.00   m     No   Sat  Dinner     4    High  14.669927
# 228       13.28  2.72   m     No   Sat  Dinner     2  Medium  20.481928
# 229       22.12  2.88   f    Yes   Sat  Dinner     2    High  13.019892
# 230       24.01  2.00   m    Yes   Sat  Dinner     4    High   8.329863
# 231       15.69  3.00   m    Yes   Sat  Dinner     3  Medium  19.120459
# 232       11.61  3.39   m     No   Sat  Dinner     2  Medium  29.198966
# 233       10.77  1.47   m     No   Sat  Dinner     2  Medium  13.649025
# 234       15.53  3.00   m    Yes   Sat  Dinner     2  Medium  19.317450
# 235       10.07  1.25   m     No   Sat  Dinner     2  Medium  12.413108
# 236       12.60  1.00   m    Yes   Sat  Dinner     2  Medium   7.936508
# 237       32.83  1.17   m    Yes   Sat  Dinner     2    High   3.563814
# 238       35.83  4.67   f     No   Sat  Dinner     3    High  13.033771
# 239       29.03  5.92   m     No   Sat  Dinner     3    High  20.392697
# 240       27.18  2.00   f    Yes   Sat  Dinner     2    High   7.358352
# 241       22.67  2.00   m    Yes   Sat  Dinner     2    High   8.822232
# 242       17.82  1.75   m     No   Sat  Dinner     2  Medium   9.820426
# 243       18.78  3.00   f     No  Thur  Dinner     2  Medium  15.974441
# 244       15.00  2.00   m     No   Sat  Dinner     4     NaN        NaN
#
# [245 rows x 9 columns]

# %% [markdown]
# #### Rename column names sex and time to gender and type

# %%
df.rename(columns={'sex':'gender','time':'type'})
# Out:
#      total_bill   tip  gender smoker   day    type  size message    tip_per
# 0         16.99  1.01  Female     No   Sun  Dinner     2  Medium   5.944673
# 1         10.34  1.66    Male     No   Sun  Dinner     3  Medium  16.054159
# 2         21.01  3.50    Male     No   Sun  Dinner     3    High  16.658734
# 3         23.68  3.31    Male     No   Sun  Dinner     2    High  13.978041
# 4         24.59  3.61  Female     No   Sun  Dinner     4    High  14.680765
# 5         25.29  4.71    Male     No   Sun  Dinner     4    High  18.623962
# 6          8.77  2.00    Male     No   Sun  Dinner     2     Low  22.805017
# 7         26.88  3.12    Male     No   Sun  Dinner     4    High  11.607143
# 8         15.04  1.96    Male     No   Sun  Dinner     2  Medium  13.031915
# 9         14.78  3.23    Male     No   Sun  Dinner     2  Medium  21.853857
# 10        10.27  1.71    Male     No   Sun  Dinner     2  Medium  16.650438
# 11        35.26  5.00  Female     No   Sun  Dinner     4    High  14.180374
# 12        15.42  1.57    Male     No   Sun  Dinner     2  Medium  10.181582
# 13        18.43  3.00    Male     No   Sun  Dinner     4  Medium  16.277808
# 14        14.83  3.02  Female     No   Sun  Dinner     2  Medium  20.364127
# 15        21.58  3.92    Male     No   Sun  Dinner     2    High  18.164968
# 16        10.33  1.67  Female     No   Sun  Dinner     3  Medium  16.166505
# 17        16.29  3.71    Male     No   Sun  Dinner     3  Medium  22.774708
# 18        16.97  3.50  Female     No   Sun  Dinner     3  Medium  20.624632
# 19        20.65  3.35    Male     No   Sat  Dinner     3    High  16.222760
# 20        17.92  4.08    Male     No   Sat  Dinner     2  Medium  22.767857
# 21        20.29  2.75  Female     No   Sat  Dinner     2    High  13.553475
# 22        15.77  2.23  Female     No   Sat  Dinner     2  Medium  14.140774
# 23        39.42  7.58    Male     No   Sat  Dinner     4    High  19.228818
# 24        19.82  3.18    Male     No   Sat  Dinner     2  Medium  16.044400
# 25        17.81  2.34    Male     No   Sat  Dinner     4  Medium  13.138686
# 26        13.37  2.00    Male     No   Sat  Dinner     2  Medium  14.958863
# 27        12.69  2.00    Male     No   Sat  Dinner     2  Medium  15.760441
# 28        21.70  4.30    Male     No   Sat  Dinner     2    High  19.815668
# 29        19.65  3.00  Female     No   Sat  Dinner     2  Medium  15.267176
# ..          ...   ...     ...    ...   ...     ...   ...     ...        ...
# 215       12.90  1.10  Female    Yes   Sat  Dinner     2  Medium   8.527132
# 216       28.15  3.00    Male    Yes   Sat  Dinner     5    High  10.657194
# 217       11.59  1.50    Male    Yes   Sat  Dinner     2  Medium  12.942192
# 218        7.74  1.44    Male    Yes   Sat  Dinner     2     Low  18.604651
# 219       30.14  3.09  Female    Yes   Sat  Dinner     4    High  10.252157
# 220       12.16  2.20    Male    Yes   Fri   Lunch     2  Medium  18.092105
# 221       13.42  3.48  Female    Yes   Fri   Lunch     2  Medium  25.931446
# 222        8.58  1.92    Male    Yes   Fri   Lunch     1     Low  22.377622
# 223       15.98  3.00  Female     No   Fri   Lunch     3  Medium  18.773467
# 224       13.42  1.58    Male    Yes   Fri   Lunch     2  Medium  11.773472
# 225       16.27  2.50  Female    Yes   Fri   Lunch     2  Medium  15.365704
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2  Medium  19.821606
# 227       20.45  3.00    Male     No   Sat  Dinner     4    High  14.669927
# 228       13.28  2.72    Male     No   Sat  Dinner     2  Medium  20.481928
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2    High  13.019892
# 230       24.01  2.00    Male    Yes   Sat  Dinner     4    High   8.329863
# 231       15.69  3.00    Male    Yes   Sat  Dinner     3  Medium  19.120459
# 232       11.61  3.39    Male     No   Sat  Dinner     2  Medium  29.198966
# 233       10.77  1.47    Male     No   Sat  Dinner     2  Medium  13.649025
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2  Medium  19.317450
# 235       10.07  1.25    Male     No   Sat  Dinner     2  Medium  12.413108
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2  Medium   7.936508
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2    High   3.563814
# 238       35.83  4.67  Female     No   Sat  Dinner     3    High  13.033771
# 239       29.03  5.92    Male     No   Sat  Dinner     3    High  20.392697
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2    High   7.358352
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2    High   8.822232
# 242       17.82  1.75    Male     No   Sat  Dinner     2  Medium   9.820426
# 243       18.78  3.00  Female     No  Thur  Dinner     2  Medium  15.974441
# 244       15.00  2.00    Male     No   Sat  Dinner     4     NaN        NaN
#
# [245 rows x 9 columns]

# %% [markdown]
# #### Bin total_bill to 4 bins

# %%
pd.cut(df['total_bill'],4)
# Out:
# 0      (15.005, 26.94]
# 1      (3.022, 15.005]
# 2      (15.005, 26.94]
# 3      (15.005, 26.94]
# 4      (15.005, 26.94]
# 5      (15.005, 26.94]
# 6      (3.022, 15.005]
# 7      (15.005, 26.94]
# 8      (15.005, 26.94]
# 9      (3.022, 15.005]
# 10     (3.022, 15.005]
# 11     (26.94, 38.875]
# 12     (15.005, 26.94]
# 13     (15.005, 26.94]
# 14     (3.022, 15.005]
# 15     (15.005, 26.94]
# 16     (3.022, 15.005]
# 17     (15.005, 26.94]
# 18     (15.005, 26.94]
# 19     (15.005, 26.94]
# 20     (15.005, 26.94]
# 21     (15.005, 26.94]
# 22     (15.005, 26.94]
# 23     (38.875, 50.81]
# 24     (15.005, 26.94]
# 25     (15.005, 26.94]
# 26     (3.022, 15.005]
# 27     (3.022, 15.005]
# 28     (15.005, 26.94]
# 29     (15.005, 26.94]
#             ...
# 215    (3.022, 15.005]
# 216    (26.94, 38.875]
# 217    (3.022, 15.005]
# 218    (3.022, 15.005]
# 219    (26.94, 38.875]
# 220    (3.022, 15.005]
# 221    (3.022, 15.005]
# 222    (3.022, 15.005]
# 223    (15.005, 26.94]
# 224    (3.022, 15.005]
# 225    (15.005, 26.94]
# 226    (3.022, 15.005]
# 227    (15.005, 26.94]
# 228    (3.022, 15.005]
# 229    (15.005, 26.94]
# 230    (15.005, 26.94]
# 231    (15.005, 26.94]
# 232    (3.022, 15.005]
# 233    (3.022, 15.005]
# 234    (15.005, 26.94]
# 235    (3.022, 15.005]
# 236    (3.022, 15.005]
# 237    (26.94, 38.875]
# 238    (26.94, 38.875]
# 239    (26.94, 38.875]
# 240    (26.94, 38.875]
# 241    (15.005, 26.94]
# 242    (15.005, 26.94]
# 243    (15.005, 26.94]
# 244    (3.022, 15.005]
# Name: total_bill, Length: 245, dtype: category
# Categories (4, interval[float64]): [(3.022, 15.005] < (15.005, 26.94] < (26.94, 38.875] < (38.875, 50.81]]

# %% [markdown]
# #### Split total_bill into 4 bins with 0-5, 6 - 10, 11-20 and above

# %%
pd.cut(df['total_bill'],bins=[0,5,10,20,60])
# Out:
# 0      (10, 20]
# 1      (10, 20]
# 2      (20, 60]
# 3      (20, 60]
# 4      (20, 60]
# 5      (20, 60]
# 6       (5, 10]
# 7      (20, 60]
# 8      (10, 20]
# 9      (10, 20]
# 10     (10, 20]
# 11     (20, 60]
# 12     (10, 20]
# 13     (10, 20]
# 14     (10, 20]
# 15     (20, 60]
# 16     (10, 20]
# 17     (10, 20]
# 18     (10, 20]
# 19     (20, 60]
# 20     (10, 20]
# 21     (20, 60]
# 22     (10, 20]
# 23     (20, 60]
# 24     (10, 20]
# 25     (10, 20]
# 26     (10, 20]
# 27     (10, 20]
# 28     (20, 60]
# 29     (10, 20]
#          ...
# 215    (10, 20]
# 216    (20, 60]
# 217    (10, 20]
# 218     (5, 10]
# 219    (20, 60]
# 220    (10, 20]
# 221    (10, 20]
# 222     (5, 10]
# 223    (10, 20]
# 224    (10, 20]
# 225    (10, 20]
# 226    (10, 20]
# 227    (20, 60]
# 228    (10, 20]
# 229    (20, 60]
# 230    (20, 60]
# 231    (10, 20]
# 232    (10, 20]
# 233    (10, 20]
# 234    (10, 20]
# 235    (10, 20]
# 236    (10, 20]
# 237    (20, 60]
# 238    (20, 60]
# 239    (20, 60]
# 240    (20, 60]
# 241    (20, 60]
# 242    (10, 20]
# 243    (10, 20]
# 244    (10, 20]
# Name: total_bill, Length: 245, dtype: category
# Categories (4, interval[int64]): [(0, 5] < (5, 10] < (10, 20] < (20, 60]]

# %% [markdown]
# #### Divide tip amount into 4 bins based on percentile

# %%
pd.qcut(df['tip'],4)
# Out:
# 0      (0.999, 2.0]
# 1      (0.999, 2.0]
# 2      (2.88, 3.55]
# 3      (2.88, 3.55]
# 4      (3.55, 10.0]
# 5      (3.55, 10.0]
# 6      (0.999, 2.0]
# 7      (2.88, 3.55]
# 8      (0.999, 2.0]
# 9      (2.88, 3.55]
# 10     (0.999, 2.0]
# 11     (3.55, 10.0]
# 12     (0.999, 2.0]
# 13     (2.88, 3.55]
# 14     (2.88, 3.55]
# 15     (3.55, 10.0]
# 16     (0.999, 2.0]
# 17     (3.55, 10.0]
# 18     (2.88, 3.55]
# 19     (2.88, 3.55]
# 20     (3.55, 10.0]
# 21      (2.0, 2.88]
# 22      (2.0, 2.88]
# 23     (3.55, 10.0]
# 24     (2.88, 3.55]
# 25      (2.0, 2.88]
# 26     (0.999, 2.0]
# 27     (0.999, 2.0]
# 28     (3.55, 10.0]
# 29     (2.88, 3.55]
#            ...
# 215    (0.999, 2.0]
# 216    (2.88, 3.55]
# 217    (0.999, 2.0]
# 218    (0.999, 2.0]
# 219    (2.88, 3.55]
# 220     (2.0, 2.88]
# 221    (2.88, 3.55]
# 222    (0.999, 2.0]
# 223    (2.88, 3.55]
# 224    (0.999, 2.0]
# 225     (2.0, 2.88]
# 226    (0.999, 2.0]
# 227    (2.88, 3.55]
# 228     (2.0, 2.88]
# 229     (2.0, 2.88]
# 230    (0.999, 2.0]
# 231    (2.88, 3.55]
# 232    (2.88, 3.55]
# 233    (0.999, 2.0]
# 234    (2.88, 3.55]
# 235    (0.999, 2.0]
# 236    (0.999, 2.0]
# 237    (0.999, 2.0]
# 238    (3.55, 10.0]
# 239    (3.55, 10.0]
# 240    (0.999, 2.0]
# 241    (0.999, 2.0]
# 242    (0.999, 2.0]
# 243    (2.88, 3.55]
# 244    (0.999, 2.0]
# Name: tip, Length: 245, dtype: category
# Categories (4, interval[float64]): [(0.999, 2.0] < (2.0, 2.88] < (2.88, 3.55] < (3.55, 10.0]]

# %% [markdown]
# <h2 style='color:red'>Draw plots using plot() method </h2>

# %% [markdown]
# #### Display bar graph for total bill amount for each day

# %%
df.groupby('day')['total_bill'].sum().plot(kind='bar')

# %% [markdown]
# #### Display bar graph with one bar for male and one for female for tip amount of each day. Use day for X axis and total tip amount for Y axis and legend for sex.

# %%
tips_data = df.pivot_table(index='day',columns='sex', values='tip')
tips_data
# Out:
# sex       Male    Female
# day
# Thur  2.980333  2.575625
# Fri   2.693000  2.781111
# Sat   3.083898  2.801786
# Sun   3.220345  3.367222

# %%
tips_data.plot(kind='bar')

# %% [markdown]
# #### Draw scatter plot comparing total_bill with size of the table

# %%
df.plot(kind='scatter',x='size',y='total_bill')

# %% [markdown]
# #### Draw a graph to show outliers in tip amount, if any

# %%
df['tip'].plot(kind='box')
