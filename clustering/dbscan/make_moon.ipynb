# %% [markdown]
# # Clustering using DBSCAN

# %% [markdown]
# ### Import libraries

# %%
import random 
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
from sklearn.datasets import make_moons
X,y = make_moons(n_samples=1000, noise=0.05)

# %%
df = pd.DataFrame(X)

# %%
df.head()
# Out:
#           0         1
# 0  0.740847 -0.484065
# 1 -0.305937  0.890395
# 2  0.654264  0.739087
# 3  1.858178 -0.167956
# 4 -0.766822  0.627918

# %%
plt.scatter(X[:,0],X[:,1])

# %%
from sklearn.cluster import DBSCAN

# %%
dbscan = DBSCAN(eps=0.20, min_samples=10)
dbscan.fit(X)
# Out:
# DBSCAN(algorithm='auto', eps=0.2, leaf_size=30, metric='euclidean',
#        metric_params=None, min_samples=10, n_jobs=None, p=None)

# %%
df['labels'] = dbscan.labels_

# %%
df.labels.value_counts()
# Out:
# 1    500
# 0    500
# Name: labels, dtype: int64

# %%
plt.scatter(X[:,0], X[:,1], c=df.labels.astype(np.float))

# %%
len(dbscan.core_sample_indices_)
# Out:
# 1000

# %%
dbscan
# Out:
# array([[ 0.74084745, -0.48406495],
#        [-0.30593682,  0.89039455],
#        [ 0.65426423,  0.73908682],
#        ...,
#        [ 0.77825152, -0.48635986],
#        [ 0.99103038,  0.13341789],
#        [-0.93774537,  0.33518661]])
